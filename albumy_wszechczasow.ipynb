# %% [markdown]
# ### Albumy wszechczasów
# Baza najlepiej sprzedających się albumów wszechczasów.

# %%
import pandas as pd
data = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [    POS                                   TITLE                    ARTIST  \
#  0     1                           GREATEST HITS                     QUEEN
#  1     2                    GOLD - GREATEST HITS                      ABBA
#  2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
#  3     4                                      21                     ADELE
#  4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
#  5     6                                THRILLER           MICHAEL JACKSON
#  6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
#  7     8                        BROTHERS IN ARMS              DIRE STRAITS
#  8     9                                     BAD           MICHAEL JACKSON
#  9    10                        GREATEST HITS II                     QUEEN
#  10   11                                 RUMOURS             FLEETWOOD MAC
# ...

# %%
data[0]
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
type(data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df = data[0]
df
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %% [markdown]
# 1. Zamień nagłówki kolumn na polskie odpowiedniki: ['TYTUŁ','ARTYSTA','ROK','MAX POZ']

# %%
df.rename(columns={"POS": "POZYCJA", "TITLE": "TYTUŁ", "ARTIST": "ARTYSTA", "YEAR": "ROK", "HIGH POSN": "MAX POZ"},inplace=True)
df
# Out:
#     POZYCJA                                   TYTUŁ                   ARTYSTA  \
# 0         1                           GREATEST HITS                     QUEEN
# 1         2                    GOLD - GREATEST HITS                      ABBA
# 2         3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3         4                                      21                     ADELE
# 4         5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5         6                                THRILLER           MICHAEL JACKSON
# 6         7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7         8                        BROTHERS IN ARMS              DIRE STRAITS
# 8         9                                     BAD           MICHAEL JACKSON
# 9        10                        GREATEST HITS II                     QUEEN
# 10       11                                 RUMOURS             FLEETWOOD MAC
# ...

# %% [markdown]
# 2. Ilu pojedynczych artystów znajduje się na liście?

# %%
df['ARTYSTA'].nunique()
# Out:
# 47

# %% [markdown]
# 3. Które zespoły pojawiają się najczęściej na liście?

# %%
df['ARTYSTA'].value_counts()
# Out:
# COLDPLAY                    3
# TAKE THAT                   3
# MICHAEL JACKSON             2
# DIDO                        2
# FLEETWOOD MAC               2
# QUEEN                       2
# ADELE                       2
# ABBA                        2
# ROBBIE WILLIAMS             2
# BEATLES                     2
# ORIGINAL SOUNDTRACK         2
# JAMES BLUNT                 1
# LEONA LEWIS                 1
# ED SHEERAN                  1
# CORRS                       1
# MICHAEL BUBLE               1
# SIMON & GARFUNKEL           1
# MEAT LOAF                   1
# VERVE                       1
# PINK FLOYD                  1
# MIKE OLDFIELD               1
# EMINEM                      1
# TRAVIS                      1
# ALANIS MORISSETTE           1
# SPICE GIRLS                 1
# DIRE STRAITS                1
# TRACY CHAPMAN               1
# GEORGE MICHAEL              1
# SNOW PATROL                 1
# JEFF WAYNE                  1
# MADONNA                     1
# ...

# %% [markdown]
# 4. Zmień nagłówki kolumn, tak aby każdy z nich rozpoczynał się od wielkiej litery, a pozostałe były wprowadzone małymi literami.

# %%
df.rename(str.capitalize, axis='columns', inplace=True)
df
# Out:
#     Pozycja                                   Tytuł                   Artysta  \
# 0         1                           GREATEST HITS                     QUEEN
# 1         2                    GOLD - GREATEST HITS                      ABBA
# 2         3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3         4                                      21                     ADELE
# 4         5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5         6                                THRILLER           MICHAEL JACKSON
# 6         7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7         8                        BROTHERS IN ARMS              DIRE STRAITS
# 8         9                                     BAD           MICHAEL JACKSON
# 9        10                        GREATEST HITS II                     QUEEN
# 10       11                                 RUMOURS             FLEETWOOD MAC
# ...

# %% [markdown]
# 5. Wyrzuć z tabeli kolumnę ‘Max Poz’

# %%
df.drop('Max poz',axis=1,inplace=True)
df
# Out:
#     Pozycja                                   Tytuł                   Artysta  \
# 0         1                           GREATEST HITS                     QUEEN
# 1         2                    GOLD - GREATEST HITS                      ABBA
# 2         3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3         4                                      21                     ADELE
# 4         5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5         6                                THRILLER           MICHAEL JACKSON
# 6         7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7         8                        BROTHERS IN ARMS              DIRE STRAITS
# 8         9                                     BAD           MICHAEL JACKSON
# 9        10                        GREATEST HITS II                     QUEEN
# 10       11                                 RUMOURS             FLEETWOOD MAC
# ...

# %% [markdown]
# 6. W którym roku wyszło najwięcej albumów znajdujących się na liście?

# %%
df['Rok'].value_counts()
# Out:
# 1987    4
# 2000    4
# 2004    3
# 1998    3
# 1977    3
# 2006    3
# 1997    3
# 1992    2
# 2005    2
# 2008    2
# 1995    2
# 1991    2
# 1973    2
# 2002    2
# 1990    1
# 1996    1
# 1989    1
# 1988    1
# 1986    1
# 1985    1
# 1999    1
# 1982    1
# 2001    1
# 2003    1
# 1981    1
# 2007    1
# 2009    1
# 2010    1
# 2011    1
# 2014    1
# 2015    1
# 1965    1
# 1967    1
# 1970    1
# 1975    1
# 1978    1
# 1984    1
# Name: Rok, dtype: int64

# %%
df.groupby('Rok').count().idxmax()
# Out:
# Pozycja    1987
# Tytuł      1987
# Artysta    1987
# dtype: int64

# %% [markdown]
# 7. Ile albumów wydanych między 1960 a 1990 rokiem włącznie znajduje się na liście?

# %%
len(df[(df['Rok']>=1960) & (df['Rok']<=1990)])
# Out:
# 22

# %% [markdown]
# 8. W którym roku wydany został najmłodszy album na liście?

# %%
df['Rok'].min()
# Out:
# 1965

# %% [markdown]
# 9. Przygotuj listę najwcześniej wydanych albumów każdego artysty, który znalazł się na liście.

# %%
grouped_df = df.groupby("Artysta").min().reset_index()
grouped_df
# Out:
#                      Artysta  index  Pozycja  \
# 0                       ABBA      1        2
# 1                      ADELE      3        4
# 2          ALANIS MORISSETTE     40       41
# 3              AMY WINEHOUSE     12       13
# 4                    BEATLES      2        3
# 5   BOB MARLEY & THE WAILERS     15       16
# 6                   COLDPLAY     30       31
# 7                      CORRS     27       28
# 8                 DAVID GRAY     25       26
# 9                       DIDO     24       25
# 10              DIRE STRAITS      7        8
# 11                ED SHEERAN     48       49
# 12                    EMINEM     54       55
# 13             FLEETWOOD MAC     10       11
# 14            GEORGE MICHAEL     52       53
# 15               JAMES BLUNT     16       17
# 16                JEFF WAYNE     36       37
# 17                     KEANE     34       35
# 18             KINGS OF LEON     32       33
# 19                 LADY GAGA     29       30
# ...

# %%
final_list = grouped_df[['Artysta', 'Tytuł', 'Rok']]
final_list
# Out:
#                      Artysta                             Tytuł   Rok
# 0                       ABBA              GOLD - GREATEST HITS  1975
# 1                      ADELE                                21  2011
# 2          ALANIS MORISSETTE                JAGGED LITTLE PILL  1995
# 3              AMY WINEHOUSE                     BACK TO BLACK  2006
# 4                    BEATLES                                 1  1967
# 5   BOB MARLEY & THE WAILERS                            LEGEND  1984
# 6                   COLDPLAY       A RUSH OF BLOOD TO THE HEAD  2000
# 7                      CORRS                   TALK ON CORNERS  1997
# 8                 DAVID GRAY                      WHITE LADDER  1998
# 9                       DIDO                     LIFE FOR RENT  2000
# 10              DIRE STRAITS                  BROTHERS IN ARMS  1985
# 11                ED SHEERAN                                 X  2014
# 12                    EMINEM           THE MARSHALL MATHERS LP  2000
# ...

# %% [markdown]
# Inny sposób na odnalezienie tych samych danych:

# %%
df.groupby('Artysta').agg({'Rok': 'min'}).reset_index()
# Out:
#                      Artysta   Rok
# 0                       ABBA  1975
# 1                      ADELE  2011
# 2          ALANIS MORISSETTE  1995
# 3              AMY WINEHOUSE  2006
# 4                    BEATLES  1967
# 5   BOB MARLEY & THE WAILERS  1984
# 6                   COLDPLAY  2000
# 7                      CORRS  1997
# 8                 DAVID GRAY  1998
# 9                       DIDO  2000
# 10              DIRE STRAITS  1985
# 11                ED SHEERAN  2014
# 12                    EMINEM  2000
# 13             FLEETWOOD MAC  1977
# 14            GEORGE MICHAEL  1998
# 15               JAMES BLUNT  2004
# 16                JEFF WAYNE  1978
# 17                     KEANE  2004
# 18             KINGS OF LEON  2008
# 19                 LADY GAGA  2008
# 20               LEONA LEWIS  2007
# 21                   MADONNA  1990
# 22                 MEAT LOAF  1977
# 23             MICHAEL BUBLE  2009
# 24           MICHAEL JACKSON  1982
# 25             MIKE OLDFIELD  1973
# ...

# %% [markdown]
# 10. Listę zapisz do pliku csv.

# %%
final_list.to_csv('albumy.csv', index=True)
